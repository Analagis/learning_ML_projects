# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bonus import FaceExpressionCompressor

# %%
fec = FaceExpressionCompressor(
    happy_archive="data/Face expression recognition/happy.zip",
    sad_archive="data/Face expression recognition/sad.zip",
    happy_label="happy",
    sad_label="sad",
    n_components=500,
    batch_size=1000
)

# %%
fec.fit()
fec.transform_all()
# Out:
# Обрабатываем веселые лица...
# Обрабатываем грустные лица...
# Преобразуем веселые лица
# Преобразуем грустные лица

# %%
fec.plot_transformation(50, src_label="sad", dst_label="happy")
# Out:
# Средние векторы различаются.
# Векторы различаются.

# %%
fec.plot_transformation(50, src_label="happy", dst_label="sad")
# Out:
# Средние векторы различаются.
# Векторы различаются.

# %%
fec.cleanup()
# Out:
# Временные файлы удалены
